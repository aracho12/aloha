# %% [markdown]
# # COHP Analysis

# %% [markdown]
# # Requirement
# `pip install monty`
# `pip install mendeleev`
# `git clone https://github.com/aracho12/aloha.git`

# %%
from aloha_cohp.cohpplot import * 

# requirement: 'COHPCAR.lobster', 'POSCAR' # default location "."

# Cohpplot(label='4', orbital={'Ru':('t2g','eg')},sum_labels=True)
# Cohpplot(label='4', sum_labels=True)
# Cohpplot(label='4',orbital={'Ru':('t2g','eg')})
Cohpplot(sum_labels=True)
# Out:
# label ele1  idx1 ele2  idx2         pair  -ICOHP  distance
#     1    O     2   Ru     0 O2(p)-Ru0(d) 2.01519  1.955089
#     2    O     3   Ru     0 O3(p)-Ru0(d) 2.01522  1.955089
#     3    O     4   Ru     0 O4(p)-Ru0(d) 1.73585  1.994772
#     4    O     4   Ru     0 O4(p)-Ru0(d) 1.73586  1.994771
#     5    O     5   Ru     0 O5(p)-Ru0(d) 1.73594  1.994763
#     6    O     5   Ru     0 O5(p)-Ru0(d) 1.73594  1.994762
#     7    O     2   Ru     1 O2(p)-Ru1(d) 1.73571  1.994765
#     8    O     2   Ru     1 O2(p)-Ru1(d) 1.73573  1.994766
#     9    O     3   Ru     1 O3(p)-Ru1(d) 1.73573  1.994765
#    10    O     3   Ru     1 O3(p)-Ru1(d) 1.73573  1.994766
#    11    O     4   Ru     1 O4(p)-Ru1(d) 2.01555  1.955082
#    12    O     5   Ru     1 O5(p)-Ru1(d) 2.01555  1.955090
# 				-ICOHP sum:21.94800
# Figure saved as cohp.png
# Data saved as cohp.tsv

# %%
Cohpplot(orbital={'Ru':('t2g','eg')})
# Out:
# label ele1  idx1 ele2  idx2           pair  -ICOHP  distance
#     1    O     2   Ru     0 O2(p)-Ru0(t2g) 1.15649  1.955089
#     1    O     2   Ru     0  O2(p)-Ru0(eg) 0.85870  1.955089
#     2    O     3   Ru     0 O3(p)-Ru0(t2g) 1.15651  1.955089
#     2    O     3   Ru     0  O3(p)-Ru0(eg) 0.85871  1.955089
#     3    O     4   Ru     0 O4(p)-Ru0(t2g) 1.34564  1.994772
#     3    O     4   Ru     0  O4(p)-Ru0(eg) 0.39021  1.994772
#     4    O     4   Ru     0 O4(p)-Ru0(t2g) 1.34565  1.994771
#     4    O     4   Ru     0  O4(p)-Ru0(eg) 0.39021  1.994771
#     5    O     5   Ru     0 O5(p)-Ru0(t2g) 1.34566  1.994763
#     5    O     5   Ru     0  O5(p)-Ru0(eg) 0.39028  1.994763
#     6    O     5   Ru     0 O5(p)-Ru0(t2g) 1.34566  1.994762
#     6    O     5   Ru     0  O5(p)-Ru0(eg) 0.39028  1.994762
#     7    O     2   Ru     1 O2(p)-Ru1(t2g) 1.34560  1.994765
#     7    O     2   Ru     1  O2(p)-Ru1(eg) 0.39011  1.994765
# ...

# %%
# Out:
# [1, 2, 3, 1, 2, 3]
